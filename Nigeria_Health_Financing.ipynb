# %% [markdown]
# <a href="https://colab.research.google.com/github/Blessing-ozoemena/Nigeria-s-Health-Financing-Crisis/blob/main/Nigeria_Health_Financing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nigeria's Health Financing Crisis: A 23-Year Analysis
# ### Data Source: World Bank (Health Nutrition and Population Statistics)
# ### Period: 2000 – 2023
# --------------------------------------------------------------------
#
# ## Project Overview
#
# This notebook presents a systematic analysis of Nigeria's health financing landscape over a 23-year period (2000–2023), using data from the World Bank's Health Nutrition and Population Statistics database.
#
# The central question guiding this analysis is: Is Nigeria investing enough in health, and is that investment translating into better outcomes for its citizens?
#
# The analysis is structured in the following stages:
# 1. Data Loading & Initial Inspection
# 2. Data Cleaning & Preprocessing
# 3. Exploratory Data Analysis (EDA)
# 4. Thematic Visualizations
# 5. Key Findings & Policy Implications
#
# ---

# %% [markdown]
# ## Section 1: Environment Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.gridspec import GridSpec
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.max_colwidth', 80)

print('Libraries loaded successfully.')
# Out:
# Libraries loaded successfully.

# %% [markdown]
# ---
# ## Section 2: Data Loading & Initial Inspection
#
# The dataset was downloaded from the World Bank DataBank portal under the **Health Nutrition and Population Statistics** collection, filtered for Nigeria across all available years.
#
# We begin by loading the file and performing an initial inspection to understand its structure.

# %%
# Loading all sheets to understand the file structure
all_sheets = pd.read_excel('/content/P_Data_Extract_From_Health_Nutrition_and_Population_Statistics (1).xlsx', sheet_name=None)
print('Sheets:', list(all_sheets.keys()))
# Out:
# Sheets: ['Data', 'Series - Metadata']

# %%
# Loading the main data sheet
raw_df = pd.read_excel('/content/P_Data_Extract_From_Health_Nutrition_and_Population_Statistics (1).xlsx', sheet_name='Data')

print(f'Shape: {raw_df.shape[0]} rows x {raw_df.shape[1]} columns')
print(f'\nColumns:')
for col in raw_df.columns:
    print(f'  - {col}')
# Out:
# Shape: 31 rows x 25 columns
#
# Columns:
#   - Year
#   - Year Code
#   - Country Name
#   - Country Code
#   - Prevalence of stunting, height for age (% of children under 5) [SH.STA.STNT.ZS]
#   - Adults (ages 15+) living with HIV [SH.DYN.AIDS]
#   - Antiretroviral therapy coverage (% of people living with HIV) [SH.HIV.ARTC.ZS]
#   - Capital health expenditure (% of GDP) [SH.XPD.KHEX.GD.ZS]
#   - Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]
#   - Domestic general government health expenditure (% of GDP) [SH.XPD.GHED.GD.ZS]
#   - Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]
#   - Domestic general government health expenditure (% of current health expenditure) [SH.XPD.GHED.CH.ZS]
#   - Domestic general government health expenditure per capita (current US$) [SH.XPD.GHED.PC.CD]
#   - Domestic private health expenditure (% of current health expenditure) [SH.XPD.PVTD.CH.ZS]
#   - External health expenditure (% of current health expenditure) [SH.XPD.EHEX.CH.ZS]
#   - Out-of-pocket expenditure (% of current health expenditure) [SH.XPD.OOPC.CH.ZS]
#   - Hospital beds (per 1,000 people) [SH.MED.BEDS.ZS]
#   - Physicians (per 1,000 people) [SH.MED.PHYS.ZS]
#   - Nurses and midwives (per 1,000 people) [SH.MED.NUMW.P3]
#   - Life expectancy at birth, total (years) [SP.DYN.LE00.IN]
#   - Maternal mortality ratio (national estimate, per 100,000 live births) [SH.STA.MMRT.NE]
#   - Mortality rate, infant (per 1,000 live births) [SP.DYN.IMRT.IN]
#   - UHC service coverage index [SH.UHC.SRVS.CV.XD]
#   - Children (0-14) living with HIV [SH.HIV.0014]
#   - ARI treatment (% of children under 5 taken to a health provider) [SH.STA.ARIC.ZS]

# %%
# Previewing raw data
raw_df.head(5)
# Out:
#    Year Year Code Country Name Country Code  \
# 0  2000    YR2000      Nigeria          NGA
# 1  2001    YR2001      Nigeria          NGA
# 2  2002    YR2002      Nigeria          NGA
# 3  2003    YR2003      Nigeria          NGA
# 4  2004    YR2004      Nigeria          NGA
#
#   Prevalence of stunting, height for age (% of children under 5) [SH.STA.STNT.ZS]  \
# 0                                                                              ..
# 1                                                                              ..
# 2                                                                              ..
# 3                                                                           42.50
# 4                                                                              ..
#
#    Adults (ages 15+) living with HIV [SH.DYN.AIDS]  \
# 0                                       1500000.00
# 1                                       1500000.00
# 2                                       1500000.00
# 3                                       1600000.00
# 4                                       1600000.00
#
#    Antiretroviral therapy coverage (% of people living with HIV) [SH.HIV.ARTC.ZS]  \
# 0                                                                            0.00
# 1                                                                            0.00
# 2                                                                            1.00
# 3                                                                            1.00
# 4                                                                            2.00
#
#   Capital health expenditure (% of GDP) [SH.XPD.KHEX.GD.ZS]  \
# 0                                                      0.00
# 1                                                      0.01
# 2                                                        ..
# 3                                                        ..
# 4                                                        ..
#
#   Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]  \
# 0                                                      3.20
# 1                                                      3.19
# 2                                                      2.49
# 3                                                      5.05
# 4                                                      4.63
#
#   Domestic general government health expenditure (% of GDP) [SH.XPD.GHED.GD.ZS]  \
# 0                                                                          0.59
# 1                                                                          0.86
# 2                                                                          0.53
# 3                                                                          0.93
# 4                                                                          1.20
#
#   Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]  \
# 0                                                                             2.37
# 1                                                                             2.78
# 2                                                                             2.74
# 3                                                                             4.01
# 4                                                                             6.55
#
#   Domestic general government health expenditure (% of current health expenditure) [SH.XPD.GHED.CH.ZS]  \
# 0                                                                            18.31
# 1                                                                            26.89
# 2                                                                            21.33
# 3                                                                            18.40
# 4                                                                            25.94
#
#   Domestic general government health expenditure per capita (current US$) [SH.XPD.GHED.PC.CD]  \
# 0                                                                             3.14
# 1                                                                             4.83
# 2                                                                             3.74
# 3                                                                             6.98
# 4                                                                            11.11
#
#   Domestic private health expenditure (% of current health expenditure) [SH.XPD.PVTD.CH.ZS]  \
# 0                                                                            64.72
# 1                                                                            66.39
# 2                                                                            71.36
# 3                                                                            75.89
# 4                                                                            67.84
#
#   External health expenditure (% of current health expenditure) [SH.XPD.EHEX.CH.ZS]  \
# 0                                                                            16.97
# 1                                                                             6.72
# 2                                                                             7.30
# 3                                                                             5.72
# 4                                                                             6.22
#
#   Out-of-pocket expenditure (% of current health expenditure) [SH.XPD.OOPC.CH.ZS]  \
# 0                                                                           60.16
# 1                                                                           60.75
# 2                                                                           65.05
# 3                                                                           72.81
# 4                                                                           64.55
#
#   Hospital beds (per 1,000 people) [SH.MED.BEDS.ZS]  \
# 0                                                ..
# 1                                                ..
# 2                                                ..
# 3                                                ..
# 4                                              0.50
#
#   Physicians (per 1,000 people) [SH.MED.PHYS.ZS]  \
# 0                                           0.27
# 1                                             ..
# 2                                             ..
# 3                                           0.26
# 4                                             ..
#
#   Nurses and midwives (per 1,000 people) [SH.MED.NUMW.P3]  \
# 0                                                      ..
# 1                                                      ..
# 2                                                      ..
# 3                                                    1.53
# 4                                                      ..
#
#   Life expectancy at birth, total (years) [SP.DYN.LE00.IN]  \
# 0                                                    47.14
# 1                                                    47.55
# 2                                                    48.02
# 3                                                    48.62
# 4                                                    49.15
#
#   Maternal mortality ratio (national estimate, per 100,000 live births) [SH.STA.MMRT.NE]  \
# 0                                                                               ..
# 1                                                                               ..
# 2                                                                               ..
# 3                                                                               ..
# 4                                                                               ..
#
#   Mortality rate, infant (per 1,000 live births) [SP.DYN.IMRT.IN]  \
# 0                                                           97.10
# 1                                                           94.60
# 2                                                           91.90
# 3                                                           89.10
# 4                                                           86.40
#
#   UHC service coverage index [SH.UHC.SRVS.CV.XD]  \
# 0                                             20
# 1                                             ..
# 2                                             ..
# 3                                             ..
# 4                                             ..
#
#   Children (0-14) living with HIV [SH.HIV.0014]  \
# 0                                            ..
# 1                                            ..
# 2                                            ..
# 3                                            ..
# 4                                            ..
#
#   ARI treatment (% of children under 5 taken to a health provider) [SH.STA.ARIC.ZS]
# 0                                                                               ..
# 1                                                                               ..
# 2                                                                               ..
# 3                                                                               33
# 4                                                                               ..

# %%
# Checking data types
raw_df.dtypes
# Out:
# Year                                                                                                         object
# Year Code                                                                                                    object
# Country Name                                                                                                 object
# Country Code                                                                                                 object
# Prevalence of stunting, height for age (% of children under 5) [SH.STA.STNT.ZS]                              object
# Adults (ages 15+) living with HIV [SH.DYN.AIDS]                                                             float64
# Antiretroviral therapy coverage (% of people living with HIV) [SH.HIV.ARTC.ZS]                              float64
# Capital health expenditure (% of GDP) [SH.XPD.KHEX.GD.ZS]                                                    object
# Current health expenditure (% of GDP) [SH.XPD.CHEX.GD.ZS]                                                    object
# Domestic general government health expenditure (% of GDP) [SH.XPD.GHED.GD.ZS]                                object
# Domestic general government health expenditure (% of general government expenditure) [SH.XPD.GHED.GE.ZS]     object
# Domestic general government health expenditure (% of current health expenditure) [SH.XPD.GHED.CH.ZS]         object
# Domestic general government health expenditure per capita (current US$) [SH.XPD.GHED.PC.CD]                  object
# Domestic private health expenditure (% of current health expenditure) [SH.XPD.PVTD.CH.ZS]                    object
# External health expenditure (% of current health expenditure) [SH.XPD.EHEX.CH.ZS]                            object
# Out-of-pocket expenditure (% of current health expenditure) [SH.XPD.OOPC.CH.ZS]                              object
# Hospital beds (per 1,000 people) [SH.MED.BEDS.ZS]                                                            object
# Physicians (per 1,000 people) [SH.MED.PHYS.ZS]                                                               object
# Nurses and midwives (per 1,000 people) [SH.MED.NUMW.P3]                                                      object
# Life expectancy at birth, total (years) [SP.DYN.LE00.IN]                                                     object
# Maternal mortality ratio (national estimate, per 100,000 live births) [SH.STA.MMRT.NE]                       object
# Mortality rate, infant (per 1,000 live births) [SP.DYN.IMRT.IN]                                              object
# UHC service coverage index [SH.UHC.SRVS.CV.XD]                                                               object
# Children (0-14) living with HIV [SH.HIV.0014]                                                                object
# ARI treatment (% of children under 5 taken to a health provider) [SH.STA.ARIC.ZS]                            object
# dtype: object

# %% [markdown]
# **Observation:**
# All indicator column would be converted to numeric data types during cleaning

# %%
# Inspecting all unique Year values (World Bank files often contain metadata rows at the bottom)
print('All values in Year column:')
print(raw_df['Year'].unique())
# Out:
# All values in Year column:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024
#  'Exponential growth rate' nan
#  'Data from database: Health Nutrition and Population Statistics'
#  'Last Updated: 02/02/2026']

# %% [markdown]
# **Observation:** The `Year` column contains non-year metadata rows at the bottom (e.g., 'Exponential growth rate', database name, last updated). These would be removed during cleaning.
